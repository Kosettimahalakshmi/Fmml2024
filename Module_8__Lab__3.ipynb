# %% [markdown]
# <a href="https://colab.research.google.com/github/Kosettimahalakshmi/Fmml2024/blob/main/Module_8__Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 06:37:30--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   112MB/s    in 0.6s
#
# 2025-03-16 06:37:31 (112 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6708   1705.07505v1  We introduce a novel framework for adversarial...  stat
# 28075  1705.05685v1  Camera parameters not only play an important r...    cs
# 22042   1404.1361v3  We propose a method for inferring the conditio...  stat
# 5237    1203.3524v1  Gaussian processes (GP) are attractive buildin...  stat
# 4129   1512.06492v1  This paper summarizes the recent progress we h...    cs
# ...             ...                                                ...   ...
# 7804   1803.04665v1  We consider the problem of near-optimal arm id...  stat
# 22400  1605.08301v2  We propose a data-driven, coarse-graining form...  stat
# 37565  1710.00310v1  In this paper we study the personalized text s...    cs
# 6594   1703.09766v1  Stochastic gradient descent based algorithms a...  stat
# 7051   1709.06109v2  In this note we prove a tight lower bound for ...  stat
#
#                                                    title  year  \
# 6708            Annealed Generative Adversarial Networks  2017
# 28075  Active Control of Camera Parameters for Object...  2017
# 22042  Learning the Conditional Independence Structur...  2014
# 5237   Speeding up the binary Gaussian process classi...  2012
# 4129   Remote Health Coaching System and Human Motion...  2015
# ...                                                  ...   ...
# 7804   Pure Exploration in Infinitely-Armed Bandit Mo...  2018
# 22400                         Predictive Coarse-Graining  2016
# 37565  Personalized Fuzzy Text Search Using Interest ...  2017
# 6594   Unifying the Stochastic Spectral Descent for R...  2017
# 7051   A Note on Tight Lower Bound for MNL-Bandit Ass...  2017
#
#                                                 keywords
# 6708   [introduce, framework, adversarial, distributi...
# 28075  [parameters, important, determining, perceived...
# 22042  [inferring, conditional, independence, dimensi...
# 5237   [processes, attractive, probabilistic, drawbac...
# 4129   [summarizes, technologies, accessible, afforda...
# ...                                                  ...
# 7804   [identification, confidence, infinitely, reser...
# 22400  [formulation, equilibrium, statistical, mechan...
# 37565  [personalized, conventional, algorithms, effic...
# 6594   [stochastic, algorithms, typically, optimizati...
# 7051   [assortment, selection, parameters, logarithmi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6708     [introduce, framework, adversarial, distributi...
# 28075    [parameters, important, determining, perceived...
# 22042    [inferring, conditional, independence, dimensi...
# 5237     [processes, attractive, probabilistic, drawbac...
# 4129     [summarizes, technologies, accessible, afforda...
#                                ...
# 7611     [investigate, normalization, technique, probab...
# 21755    [variables, populations, classified, polytomie...
# 35181    [description, knowledge, representation, forma...
# 22337    [complexity, quantification, uncertainty, exce...
# 37125    [polynomial, deterministic, algorithm, approxi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8835 words.
# Out of those 4573 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9e24fc0a-55b8-4b05-8393-a34c3a897410" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e24fc0a-55b8-4b05-8393-a34c3a897410")) {                    Plotly.newPlot(                        "9e24fc0a-55b8-4b05-8393-a34c3a897410",                        [{"x":["introduce","divergence","algorithm","distribution","objective","synthetic","nonparametric","adversarial","experiments","irrespective","generative","conjecture","continuous","annealing","balancing","framework","corollary","perceived","illumination","determining","demonstrate","performance","effectiveness","observation","conditions","different","experimental","important","evaluating","variables","parameters","quantitatively","conventional","dependent","algorithms","detection","guarantee","components","underlying","autoregressive","inferring","properties","stationary","smoothness","approaches","theoretical","independence","prescribed","parametric","consistent","asymptotically","conditional","inference","probability","numerical","sufficiently","structure","multitask","dimensional","previously","attractive","approximately","processes","requirement","expectation","posterior","computations","drawbacks","compactly","supported","propagation","alleviated","covariance","functions","substantial","classification","implementation","challenges","increasing","probabilistic","alongside","computational","regression","filtering","kinematic","unscented","generated","technologies","microsoft","affordable","parameter","investigate","accessible","summarizes","identification","structures","generates","recurrent","convolutional","assessment","potential","dependencies","leveraging","comparisons","information","automated","positives","processed","methodologies","artificial","significant","substantially","sectional","expressive","tomography","pulmonary","segmentation","abnormalities","challenging","competing","consisting","distinguish","exploiting","annotated","increases","consuming","architecture","highlighting","representations","available","sensitivity","published","dimensions","according","benchmarks","relatedness","partially","similarity","outperform","embeddings","interpret","difficult","implementations","comprehensive","occurrence","transparent","inspection","biomedical","representation","abbreviations","abstracts","complementary","extensive","interfaces","unsupervised","representing","hyperparameters","judgement","correlated","correlate","meaningful","importance","including","depending","languages","discourse","portuguese","documents","competitive","brazilian","linguistic","argumentative","knowledge","understanding","treebanks","awareness","covariates","conditioning","successful","consideration","collaborative","preferences","outperforms","restaurants","restaurant","assignment","combinations","experience","recommendation","mechanism","incorporates","assumption","overlapping","individually","interesting","diversity","reasoning","parallels","hierarchical","technique"],"y":[348,28,806,207,165,145,22,91,604,6,107,15,121,14,16,558,1,16,38,36,555,857,196,64,132,797,361,359,48,127,239,21,112,90,601,340,24,107,138,5,27,217,25,19,424,159,24,4,43,87,15,105,216,188,85,15,335,9,169,90,21,23,95,39,24,38,37,14,10,19,66,5,21,210,49,518,150,117,106,150,6,287,114,60,4,3,191,41,9,7,128,149,19,3,125,128,59,168,369,40,165,57,41,34,714,91,7,30,22,158,216,42,0,35,17,2,192,4,271,18,39,42,79,45,50,39,237,14,212,296,35,36,37,111,84,12,43,156,89,71,24,153,40,73,26,6,10,11,330,4,6,31,158,14,132,71,9,3,29,9,58,90,250,27,96,11,3,60,112,1,60,2,339,162,3,5,2,10,77,27,33,42,257,2,2,16,36,31,29,105,42,73,22,13,66,37,136,3,100,234],"type":"bar"},{"x":["introduce","divergence","algorithm","distribution","objective","synt ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4573,), (4573, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7941666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Dual</span> <span style=''>Memory</span> <span style=''>Neural</span> <span style=''>Computer</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Asynchronous</span> <span style=''>Two</span> <span style=''>view</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sequential</span> <span style=''>Learning</span> <br/><br/><span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>core</span> <span style=''>tasks</span> <span style=''>in</span> <span style=''>multi</span> <span style=''>view</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>to</span> <span style=''>capture</span> <span style='background-color:rgba(0, 255, 0, 0.5244755244755245);'>relations</span> <span style=''>among</span> <span style=''>views</span> <span style=''>For</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>data</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5244755244755245);'>relations</span> <span style=''>not</span> <span style=''>only</span> <span style=''>span</span> <span style=''>across</span> <span style=''>views</span> <span style=''>but</span> <span style=''>also</span> <span style=''>extend</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>throughout</span> <span style=''>the</span> <span style=''>view</span> <span style=''>length</span> <span style=''>to</span> <span style=''>form</span> <span style=''>long</span> <span style=''>term</span> <span style=''>intra</span> <span style=''>view</span> <span style=''>and</span> <span style=''>inter</span> <span style=''>view</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>memory</span> <span style='background-color:rgba(0, 255, 0, 0.3090909090909091);'>augmented</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>model</span> <span style=''>that</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>model</span> <span style=''>these</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>between</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>asynchronous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>views</span> <span style=''>Our</span> <span style=''>model</span> <span style=''>uses</span> <span style=''>two</span> <span style=''>encoders</span> <span style=''>for</span> <span style=''>reading</span> <span style=''>from</span> <span style=''>and</span> <span style=''>writing</span> <span style=''>to</span> <span style=''>two</span> <span style=''>external</span> <span style=''>memories</span> <span style=''>for</span> <span style=''>encoding</span> <span style=''>input</span> <span style=''>views</span> <span style=''>The</span> <span style=''>intra</span> <span style=''>view</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>and</span> <span style=''>the</span> <span style=''>long</span> <span style=''>term</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>are</span> <span style=''>captured</span> <span style=''>by</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>memories</span> <span style=''>during</span> <span style=''>this</span> <span style=''>encoding</span> <span style=''>process</span> <span style=''>There</span> <span style=''>are</span> <span style=''>two</span> <span style=''>modes</span> <span style=''>of</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accessing</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Localized</span> <span style=''>Lasso</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>localized</span> <span style=''>Lasso</span> <span style=''>which</span> <span style=''>is</span> <span style=''>suited</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>that</span> <span style=''>are</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>and</span> <span style=''>have</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>power</span> <span style=''>in</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>d</span> <span style=''>and</span> <span style=''>small</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>n</span> <span style=''>More</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>function</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>local</span> <span style=''>sparse</span> <span style=''>models</span> <span style=''>one</span> <span style=''>at</span> <span style=''>each</span> <span style=''>data</span> <span style=''>point</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>sample</span> <span style=''>wise</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>to</span> <span style=''>borrow</span> <span style=''>strength</span> <span style=''>across</span> <span style=''>the</span> <span style=''>models</span> <span style=''>and</span> <span style=''>sample</span> <span style=''>wise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exclusive</span> <span style=''>group</span> <span style=''>sparsity</span> <span style=''>(aka</span> <span style=''>ell</span> <span style=''>12</span> <span style=''>norm)</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diversity</span> <span style=''>into</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>feature</span> <span style=''>sets</span> <span style=''>in</span> <span style=''>the</span> <span style=''>local</span> <span style=''>models</span> <span style=''>The</span> <span style=''>local</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>of</span> <span style=''>their</span> <span style=''>sparsity</span> <span style=''>patterns</span> <span style=''>The</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>is</span> <span style=''>convex</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>has</span> <span style=''>a</span> <span style=''>globally</span> <span style=''>optimal</span> <span style=''>solution</span> <span style=''>Moreover</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>Exact</span> <span style='background-color:rgba(255, 0, 0, 0.32182103610675045);'>Inference</span> <span style=''>in</span> <span style=''>Planar</span> <span style=''>Ising</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>give</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>the</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>lowest</span> <span style=''>energy</span> <span style=''>(ground)</span> <span style=''>states</span> <span style=''>worst</span> <span style=''>margin</span> <span style=''>violators</span> <span style=''>log</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>marginal</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>in</span> <span style=''>certain</span> <span style=''>binary</span> <span style='background-color:rgba(255, 0, 0, 0.36170212765957444);'>undirected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>provides</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interesting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>to</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>graph</span> <span style=''>cut</span> <span style=''>paradigm</span> <span style=''>in</span> <span style=''>that</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>impose</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>submodularity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>instead</span> <span style=''>we</span> <span style=''>require</span> <span style=''>planarity</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5238095238095238);'>correspondence</span> <span style=''>with</span> <span style=''>perfect</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>matchings</span> <span style=''>(dimer</span> <span style=''>coverings)</span> <span style=''>in</span> <span style=''>an</span> <span style=''>expanded</span> <span style=''>dual</span> <span style=''>graph</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implement</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>while</span> <span style=''>delegating</span> <span style=''>complex</span> <span style=''>but</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understood</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>subproblems</span> <span style=''>(planar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>maximum</span> <span style=''>weight</span> <span style=''>perfect</span> <span style=''>matching)</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='ba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style=''>Learning</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transferable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representations</span> <span style=''>across</span> <span style=''>Domains</span> <span style=''>and</span> <span style=''>Tasks</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transferable</span> <span style=''>across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>domains</span> <span style=''>and</span> <span style=''>tasks</span> <span style=''>in</span> <span style=''>a</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>manner</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>battles</span> <span style=''>domain</span> <span style=''>shift</span> <span style=''>with</span> <span style=''>a</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>loss</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>to</span> <span style=''>novel</span> <span style=''>task</span> <span style=''>using</span> <span style=''>a</span> <span style=''>metric</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>Our</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimized</span> <span style=''>on</span> <span style=''>labeled</span> <span style=''>source</span> <span style=''>data</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>or</span> <span style=''>sparsely</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>in</span> <span style=''>the</span> <span style=''>target</span> <span style=''>domain</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>shows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compelling</span> <span style=''>results</span> <span style=''>on</span> <span style=''>novel</span> <span style=''>classes</span> <span style=''>within</span> <span style=''>a</span> <span style=''>new</span> <span style=''>domain</span> <span style=''>even</span> <span style=''>when</span> <span style=''>only</span> <span style=''>a</span> <span style=''>few</span> <span style=''>labeled</span> <span style=''>examples</span> <span style=''>per</span> <span style=''>class</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforming</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prevalent</span> <span style=''>fine</span> <span style=''>tuning</span> <span style=''>approach</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>on</span> <span style=''>the</span> <span style=''>tra ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.0482611781405252)
# 	evaluation (0.09403832505322925)
# 	knowledge (0.12029808374733854)
# 	architecture (0.08410220014194464)
# 	segmentation (0.06813342796309439)
# 	detection (0.12065294535131299)
# 	information (0.25337118523775726)
# 	convolutional (0.13094393186657205)
# 	different (0.28282469836763663)
# 	recognition (0.13413768630234207)
#
# Some Statistics words are:
# 	theoretical (0.1503531786074672)
# 	stochastic (0.14026236125126135)
# 	statistical (0.16094853683148336)
# 	variables (0.1442986881937437)
# 	estimation (0.17961654894046417)
# 	distribution (0.18314833501513622)
# 	algorithm (0.40514631685166497)
# 	dimensional (0.1927346115035318)
# 	regression (0.17608476286579214)
# 	inference (0.2124117053481332)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6e41b25f-7aad-46b0-932e-7c4bd119c2c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e41b25f-7aad-46b0-932e-7c4bd119c2c2")) {                    Plotly.newPlot(                        "6e41b25f-7aad-46b0-932e-7c4bd119c2c2",                        [{"x":["introduce","divergence","algorithm","distribution","objective","synthetic","nonparametric","adversarial","experiments","irrespective","generative","conjecture","continuous","annealing","balancing","framework","corollary","perceived","illumination","determining","demonstrate","performance","effectiveness","observation","conditions","different","experimental","important","evaluating","variables","parameters","quantitatively","conventional","dependent","algorithms","detection","guarantee","components","underlying","autoregressive","inferring","properties","stationary","smoothness","approaches","theoretical","independence","prescribed","parametric","consistent","asymptotically","conditional","inference","probability","numerical","sufficiently","structure","multitask","dimensional","previously","attractive","approximately","processes","requirement","expectation","posterior","computations","drawbacks","compactly","supported","propagation","alleviated","covariance","functions","substantial","classification","implementation","challenges","increasing","probabilistic","alongside","computational","regression","filtering","kinematic","unscented","generated","technologies","microsoft","affordable","parameter","investigate","accessible","summarizes","identification","structures","generates","recurrent","convolutional","assessment","potential","dependencies","leveraging","comparisons","information","automated","positives","processed","methodologies","artificial","significant","substantially","sectional","expressive","tomography","pulmonary","segmentation","abnormalities","challenging","competing","consisting","distinguish","exploiting","annotated","increases","consuming","architecture","highlighting","representations","available","sensitivity","published","dimensions","according","benchmarks","relatedness","partially","similarity","outperform","embeddings","interpret","difficult","implementations","comprehensive","occurrence","transparent","inspection","biomedical","representation","abbreviations","abstracts","complementary","extensive","interfaces","unsupervised","representing","hyperparameters","judgement","correlated","correlate","meaningful","importance","including","depending","languages","discourse","portuguese","documents","competitive","brazilian","linguistic","argumentative","knowledge","understanding","treebanks","awareness","covariates","conditioning","successful","consideration","collaborative","preferences","outperforms","restaurants","restaurant","assignment","combinations","experience","recommendation","mechanism","incorporates","assumption","overlapping","individually","interesting","diversity","reasoning","parallels","hierarchical","technique","distributions","rectangular","associated","architectures","intrusion","interestingly","consistency","embedding","extraction","clustering","established","emphdirectly","estimating","corresponding","unreliable","necessarily","geometric","convergence","particularly","relatively","challenge","computing","technical","derivatives","associating","estimated","establish","developed","derivative","experimentally","approximates","estimator","estimation","significantly","multimodal","characterization","correlation","heterogeneously","retrieval","competitively","described","applications","multitype","prediction","baselines","integrate","naturally","integrates","histograms","importantly","homogeneous","exposition","uncertainty","particula ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sectional
# 	emphdirectly
# 	exposition
# 	polyhedral
# 	jackknife
# 	perceptible
# 	dominates
# 	debiasing
# 	complexes
# 	administrative
# 	nonparanormal
# 	inhomogeneity
# 	stringent
# 	kleinberg
# 	functoriality
# 	reparameterizing
# 	cumulants
# 	quadratically
# 	permitted
# 	confounder
# Some words which never appear in Statistics papers:
# 	illumination
# 	microsoft
# 	abbreviations
# 	judgement
# 	discourse
# 	argumentative
# 	treebanks
# 	disjunctions
# 	committed
# 	decidable
# 	demonstrably
# 	translator
# 	reinforced
# 	pheromone
# 	transcriptions
# 	resourced
# 	navigation
# 	assistant
# 	experiences
# 	concurrently

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.053155436143254e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7525
